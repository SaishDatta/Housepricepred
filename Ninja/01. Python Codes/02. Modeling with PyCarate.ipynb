# %%
# Import required libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

pd.set_option('display.max_columns', None)

# %%
#Import preprecessed data

df=pd.read_csv('/content/drive/MyDrive/Projects/Kaggle/02. House Price Prediction/01. DataSet/01_Preprocessed_data.csv')
print("Shape:",df.shape)
df.sample(5)
# Out:
# Shape: (1460, 223)
#       Id  MSSubClass  LotFrontage  LotArea  LotShape  OverallQual  \
# 961  962          60         60.0    12227         2            6
# 358  359          80         92.0     6930         2            5
# 795  796          60         70.0     8400         3            6
# 800  801          60         79.0    12798         2            6
# 527  528          60         67.0    14948         2            9
#
#      OverallCond  MasVnrArea  ExterQual  ExterCond  BsmtQual  BsmtCond  \
# 961            7       424.0          3          4       4.0       4.0
# 358            4       120.0          3          3       3.0       3.0
# 795            6       130.0          3          3       4.0       3.0
# 800            5         0.0          3          3       4.0       3.0
# 527            5       268.0          5          3       5.0       3.0
#
#      BsmtExposure  BsmtFinType1  BsmtFinSF1  BsmtFinType2  BsmtFinSF2  \
# ...

# %%
# Setting up a PyCaret model

#!pip install pycaret
from pycaret.regression import *

model = setup(df, target = 'SalePrice')
# Out:
# <style type="text/css">
# #T_5bda0_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_5bda0" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5bda0_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_5bda0_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5bda0_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_5bda0_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_5bda0_row0_col1" class="data row0 col1" >8890</td>
#     </tr>
#     <tr>
#       <th id="T_5bda0_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_5bda0_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_5bda0_row1_col1" class="data row1 col1" >SalePrice</td>
#     </tr>
#     <tr>
#       <th id="T_5bda0_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
# Comparing various models' performance using PyCarate

best=compare_models()
# Out:
# <style type="text/css">
# #T_337bd th {
#   text-align: left;
# }
# ...

# %%
print(best)
# Out:
# GradientBoostingRegressor(random_state=8890)

# %%
# Tuning the best model

untuned_model= create_model('gbr')
tuned_model= tune_model(untuned_model)
# Out:
# <style type="text/css">
# #T_3fd47_row10_col0, #T_3fd47_row10_col1, #T_3fd47_row10_col2, #T_3fd47_row10_col3, #T_3fd47_row10_col4, #T_3fd47_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_3fd47" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3fd47_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_3fd47_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_3fd47_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_3fd47_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_3fd47_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_3fd47_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
# ...

# %%
print(tuned_model)
# Out:
# GradientBoostingRegressor(random_state=8890)

# %%
#plot_model(tuned_model, plot = 'learning')
#predict_model(tuned_model, data = new_data)

# %%
# Saving the best model

save_model(tuned_model, '/content/drive/MyDrive/Projects/Kaggle/02. House Price Prediction/03. Saved Models/01.PyCarate_best_gbr')
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=FastMemory(location=/tmp/joblib),
#           steps=[('numerical_imputer',
#                   TransformerWrapper(include=['Id', 'MSSubClass', 'LotFrontage',
#                                               'LotArea', 'LotShape',
#                                               'OverallQual', 'OverallCond',
#                                               'MasVnrArea', 'ExterQual',
#                                               'ExterCond', 'BsmtQual',
#                                               'BsmtCond', 'BsmtExposure',
#                                               'BsmtFinType1', 'BsmtFinSF1',
#                                               'BsmtFinType2', 'BsmtFinSF2',
#                                               'BsmtUnfSF', 'TotalBsmtSF',
#                                               'Heating...
#                                               'LowQualFinSF', 'GrLivArea',
# ...

# %%
#loaded_model=load_model('/content/drive/MyDrive/Projects/Kaggle/02. House Price Prediction/03. Saved Models/01.PyCarate_best_gbr')
